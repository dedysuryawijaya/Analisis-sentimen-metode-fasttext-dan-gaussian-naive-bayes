# %%
import pandas as pd
import numpy as np
import json

# %%
pd = pd.read_json("sentimen_analisis.json")

# %%
pd.sort_values('polarity').head(10)
# Out:
#                                                    text               author  \
# 2751  Dibujuk rayu dengan BLT BBM yg hanya smentara ...         Dheila Grape
# 1393   @fabioSmd01  yg tdk mndukung itu yg malasnya ...                  MSK
# 1376  Rakyat yang mana? Jangan mengatasnamakan rakya...          Edwin edwin
# 2481  Miskin tp pake hp bisa nonton youtube\n\nApa m...    tantan hadiansyah
# 2366  Butuh pemimpin yg pro rakyat Indonesia butuh p...         Salaka Domas
# 1466   @dedi riyan  haaalaaahhh loe nya aja yg kuran...  Tetaptegar 69 Tegar
# 1777                          Klo ga salah yg demo pdip         Eko Rusmawan
# 2925  Ibu Mentri, kau bikin susah masyarakat kecil t...                 Aida
# 1421           @dedi riyan  BBM itu kebutuhan apa gak??              JAVANET
# 1398               Kasian rakyat kecil yg gajiy sedikit        Yutiah Yutiah
#
#                                                   emoji  \
# 2751  Dibujuk rayu dengan BLT BBM yg hanya smentara ...
# ...

# %%
pd.sort_values('polarity',ascending=False).head(10)
# Out:
#                                                    text               author  \
# 94                          @Gaya Baru  wkwwkw 🤣🤣🤣🤣🤣🤣🤣🤣     @PELANGI_SENJA73
# 2806          Bu mega menangis melihat ini.....😭😭😭😭😭😭😭😭        Deden Nuryadi
# 502          @Adul Mega  umumin naik pas hari libur..🤣🤣            DON PICEK
# 1586  Amin.\n\nSemoga naikanlah rezeki kami lebih ke...  TONY ABU HANIF vlog
# 399                                @Adul Mega  Hoaks🤣🤣🤣        Rain Mokoagow
# 2041            @Tonny Fernando  pake kipas anginn..🤣🤣🤣  Irman Fauzi Channel
# 869                               @Anjas Setiawan  🤣🤣🤣👍             Eful Tea
# 1435                                      @JAVANET  🤣🤣🤣           dedi riyan
# 16    Mantttaaapppp....semoga allah swt  menkhabul k...           Papa Hakim
# 1049                  🤣🤣Uda harga mati....tidak berubah           Dance Neno
#
#                                                   emoji  \
# 94    Baru wkwwkw berguling-guling di lantai tertawa...
# ...

# %%
pd.count()
# Out:
# text           3000
# author         3000
# emoji          3000
# cleantext      3000
# terbilang      3000
# tokenized      3000
# delangka       3000
# normalisasi    3000
# stemmed        3000
# polarity       3000
# label          3000
# dtype: int64

# %%
pd.groupby(["label"]).count()
# Out:
#          text  author  emoji  cleantext  terbilang  tokenized  delangka  \
# label
# negatif  2041    2041   2041       2041       2041       2041      2041
# positif   959     959    959        959        959        959       959
#
#          normalisasi  stemmed  polarity
# label
# negatif         2041     2041      2041
# positif          959      959       959
